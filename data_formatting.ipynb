# %%
import pandas as pd

# %%
df = pd.read_csv("cs_data_long.csv")

# %%
df = df.sort_values(by = ['Number', 'Year', 'Term'])

# %%
df = df[["Number", "Course Title", "Year", "Term", "GPA", "Total", "A+", "A", "A-", 
         "B+", "B", "B-", "C+", "C", "C-", "D+", "D", "D-", "F", "YearTerm"]]

# %%
df
# Out:
#      Number                  Course Title  Year Term       GPA  Total   A+  \
# 0       101  Intro Computing: Engrg & Sci  2010   fa  3.110559    465   49
# 2       101  Intro Computing: Engrg & Sci  2010   sp  3.203275    455   66
# 3       101  Intro Computing: Engrg & Sci  2011   fa  3.257814    462  115
# 4       101  Intro Computing: Engrg & Sci  2011   sp  3.391371    474  106
# 8       101  Intro Computing: Engrg & Sci  2012   fa  3.072227    449   86
# 5       101  Intro Computing: Engrg & Sci  2013   fa  2.901158    518   82
# 6       101  Intro Computing: Engrg & Sci  2013   sp  3.185330    531  104
# 7       101  Intro Computing: Engrg & Sci  2014   fa  2.633754    666   79
# 1       101  Intro Computing: Engrg & Sci  2014   sp  3.038503    521  113
# 9       101  Intro Computing: Engrg & Sci  2015   fa  3.112954    694    7
# 10      101  Intro Computing: Engrg & Sci  2015   sp  2.949956    677  116
# ...

# %%
df.to_csv("cs_data_long.csv", index = False)
